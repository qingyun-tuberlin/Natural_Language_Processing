# %% [markdown]
# # Task 1: Multilingual Transfer and Translation in Medical Social Media NLP (60%)
#
# In this exercise, you will study multilingual generalization and cross-lingual transfer in
# NLP models using medical social media data. You will work with data from SMM4H 2025
# (Task 1) and analyze how model performance differs across languages, multilingual
# training setups, and machine translation–based approaches.

# %% [markdown]
# ## Task 1.1: Language Selection, Data Preparation, and Splits (10%)
#
# 1. **Select three languages available in the dataset:**
#    - **a.** Two languages will be used for **training**
#    - **b.** One language will be used for **evaluation only** (zero-shot setting)
#
# 2. **Redefine the provided validation sets as test sets.**
#
# 3. **Create new validation sets by sampling from the training data.**
#    - **a.** Report dataset sizes and language distributions.
#
# 4. **Apply necessary preprocessing steps to prepare the data for Transformer-based models.**
#    - **a.** Describe and justify all preprocessing decisions.
#
# 5. **Select a subset (reasonable size) of the English training data and use machine translation to translate the data into the third language.**
#    - **a.** Use, for instance, an LLM or another tool of your choice to conduct the translation.
#      One option might be an LLM of the Academic Cloud
#      (https://academiccloud.de/).

# %% [markdown]
# ## Task 1.2: Multilingual Data Exploration and Analysis (10%)
#
# Perform an exploratory analysis of the selected languages, similar to Exercise 1.
#
# - **Analyze:**
#   - Label distributions per language
#   - Dataset size differences
#   - Linguistic characteristics relevant to the task
#
# - **Conduct manual inspection of samples** (ideally across languages) to identify:
#   - Translation artifacts
#   - Language-specific phenomena
#   - Annotation ambiguities
#
# Summarize findings that may affect multilingual modeling.

# %% [markdown]
# ## Task 1.3: Multilingual and Cross-Lingual Modeling (25%)
#
# Train and evaluate Transformer-based models under different training setups:
#
# ### 1. Monolingual models
# - **a.** Train one model per training language
# - **b.** Evaluate on the corresponding test language
#
# ### 2. Multilingual model
# - **a.** Train a single multilingual model on the combined training languages
# - **b.** Evaluate on:
#   - **i.** Seen languages
#   - **ii.** The unseen (zero-shot) language
#
# ### 3. Machine translation–based evaluation
# - **a.** Train a model on:
#   - a) English data
#   - b) a multilingual model
#   - c) a model trained on the translations
# - **b.** Evaluate them on the test set of the 3rd language
#
# Use the **same model architecture** across setups where possible.

# %% [markdown]
# ## Task 1.4: Evaluation, Error Analysis, and Cross-Lingual Comparison (15%)
#
# 1. **Present evaluation results** using appropriate metrics for all setups.
#
# 2. **Compare performance across:**
#    - **a.** Monolingual vs multilingual training
#    - **b.** Seen vs unseen languages (zero-shot)
#    - **c.** Native-language vs machine-translated evaluation
#
# 3. **Conduct a cross-lingual error analysis**, focusing on:
#    - **a.** Language-specific failure cases
#    - **b.** Errors introduced by translation
#    - **c.** Differences in robustness across languages
#
# 4. **Discuss:**
#    - **a.** When multilingual training helps or hurts
#    - **b.** The limitations of cross-lingual transfer in medical social media text
#    - **c.** Practical implications for multilingual medical NLP systems

# %% [markdown]
# # Task 2: Classical ML vs LLMs on Structured Data (40%)
#
# In this final task, you will explore how modern NLP and LLM-based approaches compare
# to classical machine learning models when applied to a small, fully structured dataset.
# The goal is not to achieve state-of-the-art performance, but to critically analyze modeling
# paradigms and their limitations.
# Dataset:
#
# **Iris Flower Dataset**
#
# https://www.kaggle.com/datasets/arshid/iris-flower-dataset

# %% [markdown]
# ## Task 2.1: Classical Baseline on Structured Data (5%)
#
# 1. Split the dataset into train, validation, and test sets.
# 2. Train a tree-based classifier (e.g. Decision Tree or Random Forest).
# 3. Evaluate the model on the test set and report results.
# 4. Briefly discuss:
#     - a. Model behavior
#     - b. Feature importance (if available)
#     - c. Strengths and limitations of this approach

# %% [markdown]
# ## Task 2.2: Textification and Transformer-Based Modeling (10%)
#
# 1. Convert the structured Iris data into **two different textual representations**, for
# example:
#     - a. Natural-language descriptions of feature values
#     - b. Compact numeric or semi-structured text formats
# 2. Justify your design choices.
# 3. Train and evaluate a **Transformer-based model** on the textified data.
# 4. Compare results across text representations.

# %% [markdown]
# ## Task 2.3: LLM-Based Prediction and Hybrid Modeling (15%)
#
# 1. **Evaluate an LLM** in a **few-shot learning** setup using examples from the training data.
#
# 2. **Analyze prediction quality and reasoning behavior.**
#
# 3. **Extend the LLM with additional structured information** derived from the classical model, for example:
#    - **a.** Feature importance
#    - **b.** Decision rules
#
# 4. **Compare:**
#    - **a.** LLM alone
#    - **b.** LLM augmented with classical model information

# %% [markdown]
# ## Task 2.4: Comparative Analysis and Reflection (10%)
#
# - Analyze and compare all approaches:
#     -  Classical tree-based model
#     -  Transformer on textified data
#     -  LLM-based prediction (with and without structured guidance)
